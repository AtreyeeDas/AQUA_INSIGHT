# %% [markdown]
# <a href="https://colab.research.google.com/github/AtreyeeDas/Water-Portability-Analysis/blob/main/WaterPortabilityAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import warnings
import google.generativeai as genai
from google.generativeai import types

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

warnings.simplefilter("ignore")

import kagglehub

# %%
# Download dataset from Kaggle
path = kagglehub.dataset_download("uom190346a/water-quality-and-potability")
filepath = next(os.path.join(dirname, filenames[0]) for dirname, _, filenames in os.walk(path) if filenames)
df = pd.read_csv(filepath)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.11).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/uom190346a/water-quality-and-potability?dataset_version_number=2...
# 100%|██████████| 251k/251k [00:00<00:00, 60.0MB/s]
# Extracting files...

# %%
# Handle missing values
df.fillna(df.median(), inplace=True)

# Split features and target
X = df.drop("Potability", axis=1)
y = df.Potability

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=18, stratify=y)

# Balance data
smt = SMOTE()
X_train, y_train = smt.fit_resample(X_train, y_train)

# Normalize data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Train a RandomForest model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
def predict_potability(user_input):
    """Predicts water potability from user input."""
    input_data = np.array(user_input).reshape(1, -1)
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    result = "\n💧 Water Quality Prediction 💧\n" + "="*30 + "\n"
    result += f"🔍 Analyzing water sample...\n"
    result += "✅ Safe to Drink! 😊" if prediction[0] == 1 else "⚠️ Not Safe for Drinking! ❌"
    return result

# %%
def analyze_with_gemini(user_input):
    """Analyzes water quality using Gemini API."""
    api_key = "AIzaSyB6TYePHsMOvGhgxXP-d-q5w4-KEuqRkQo"
    if not api_key:
        return "Gemini API key not found."

    genai.configure(api_key=api_key)
    model_name = "gemini-2.5-pro-exp-03-25"
    prompt = f"Given the water parameters {user_input} for  the format pH,Hardness (mg/L),Total Dissolved Solids (TDS) (mg/L),Chloramines (mg/L),Sulfate (mg/L),Conductivity (µS/cm), Organic Carbon (mg/L), Trihalomethanes (µg/L), Turbidity (NTU), is the water safe? If not, what are the contamination reasons and purification methods?"
    response = genai.GenerativeModel(model_name).generate_content(prompt)
    gemini_result = "\n🤖 AI Analysis from Gemini API 🤖\n" + "="*35 + "\n"
    gemini_result += response.text if response else "❌ No response from Gemini API."
    return gemini_result

# %%
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.073546
# 3273  9.419510  175.762646  33155.578218     7.350233  333.073546
# 3274  5.126763  230.603758  11983.869376     6.303357  333.073546
# 3275  7.874671  195.102299  17404.177061     7.509306  333.073546
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225        66.622485   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
# Collect user input
print("Enter water parameters in the following order:")
print(", ".join(X.columns))
user_input = []
for col in X.columns:
    value = float(input(f"Enter value for {col}: "))
    user_input.append(value)
# Out:
# Enter water parameters in the following order:
# ph, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic_carbon, Trihalomethanes, Turbidity
# Enter value for ph: 9
# Enter value for Hardness: 350
# Enter value for Solids: 40000
# Enter value for Chloramines: 8
# Enter value for Sulfate: 400
# Enter value for Conductivity: 300
# Enter value for Organic_carbon: 15
# Enter value for Trihalomethanes: 65
# Enter value for Turbidity: 5

# %%
# Predict water quality and Get Gemini API Analysis
prediction = predict_potability(user_input)
gemini_analysis = analyze_with_gemini(user_input)

# %%
# Display details
print(prediction)
print(gemini_analysis)
# Out:
# 💧 Water Quality Prediction 💧
# ==============================
# 🔍 Analyzing water sample...
# ⚠️ Not Safe for Drinking! ❌
#
# 🤖 AI Analysis from Gemini API 🤖
# ===================================
# Based on standard drinking water guidelines (like those from the WHO or EPA), let's analyze each parameter:
#
# 1.  **pH: 9.0**
#     *   Standard Range: Typically 6.5 - 8.5.
#     *   Assessment: **High**. Slightly outside the recommended range. High pH can affect taste and potentially piping.
#
# 2.  **Hardness: 350.0 mg/L**
#     *   Standard Range: No strict health limit, but >300 mg/L is considered very hard.
#     *   Assessment: **Very High**. Primarily an aesthetic issue (scaling, soap lathering, taste) rather than a direct health risk according to most standards.
#
# 3.  **Total Dissolved Solids (TDS): 40000.0 mg/L**
#     *   Standard Range: EPA secondary standard is 500 mg/L. WHO suggests < 600 mg/L is good, > 1200 mg/L is unacceptable.
#     *   Assessment: **Extremely High**. This level is far beyond any acceptable limit for drinking water and is comparable to seawater (average ~35,000 mg/L) or highly saline brackish water. This is the most critical issue.
#
# 4.  **Chloramines: 8.0 mg/L**
#     *   Standard Range: EPA Maximum Residual Disinfectant Level (MRDL) is 4.0 mg/L.
#     *   Assessment: **High**. Exceeds the maximum allowable limit for disinfectants. Can cause taste/odor issues and potential irritation.
#
# 5.  **Sulfate: 400.0 mg/L**
#     *   Standard Range: EPA secondary standard is 250 mg/L.
#     *   Assessment: **High**. Exceeds the limit. High sulfate can have a laxative effect and contribute to taste issues.
#
# 6.  **Conductivity: 300.0 µS/cm**
#     *   Standard Range: No strict limit, but related to TDS. Typically TDS (mg/L) ≈ Conductivity (µS/cm) * (0.55-0.7).
#     *   Assessment: **Inconsistent**. This conductivity value is extremely low for a TDS of 40,000 mg/L (which would typically yield conductivity > 50,000 µS/cm). Assuming the TDS value is the primary concern reported, this conductivity reading seems erroneous or suggests unusual ionic composition. However, focusing on the reported TDS value is critical.
#
# 7.  **Organic Carbon: 15.0 mg/L**
#     *   Standard Range: No strict MCL, but high levels (> 2-4 mg/L) are undesirable as they can indicate contamination and act as precursors for disinfection byproducts.
#     *   Assessment: **High**. Indicates a significant amount of organic matter.
#
# 8.  **Trihalomethanes (THMs): 65.0 µg/L**
#     *   Standard Range: EPA Maximum Contaminant Level (MCL) is 80 µg/L (total THMs).
#     *   Assessment: **Acceptable**. Within the standard limit, though elevated Organic Carbon could lead to higher THMs under different disinfection conditions.
#
# 9.  **Turbidity: 5.0 NTU**
#     *   Standard Range: EPA requires < 1 NTU (ideally < 0.3 NTU) for effective disinfection. Some regulations may have an absolute maximum of 5 NTU, but it's generally considered poor quality.
#     *   Assessment: **High**. Exceeds ideal limits and potentially the maximum allowable limit. High turbidity can interfere with disinfection and indicate suspended particles.
#
# **Conclusion: Is the water safe?**
#
# **NO, the water is definitely NOT SAFE for drinking.**
#
# **Contamination Reasons:**
#
# Multiple parameters significantly exceed safe drinking water standards:
#
# 1.  **Extremely High Total Dissolved Solids (TDS):** This is the most severe issue, making the water highly saline and unpalatable, potentially indicating brackish water, seawater intrusion, or severe industrial contamination.
# 2.  **High Chloramines:** Exceeds safe disinfectant levels.
# 3.  **High Sulfate:** Exceeds limits, potentially causing gastrointestinal issues.
# 4.  **High pH:** Outside the acceptable range.
# 5.  **High Organic Carbon:** Indicates contamination and potential for byproduct formation.
# 6.  **High Turbidity:** Interferes with disinfection and indicates suspended solids.
# 7.  **(Very High Hardness):** While primarily aesthetic, it contributes to the poor water quality.
#
# *(Note: The conductivity value appears inconsistent with the TDS value and might be an error in measurement or reporting. However, the other parameters clearly indicate the water is unsafe).*
#
# **Purification Methods:**
#
# Treating water with such extreme TDS requires advanced methods, typically used in desalination:
#
# 1.  **Pre-treatment (Essential):**
#     *   **Sediment Filtration:** To remove the high turbidity (suspended particles). Needs to be robust (e.g., multi-stage filtration starting with larger micron ratings down to 1-5 microns). This protects downstream equipment.
#     *   **Activated Carbon Filtration (Catalytic Carbon):** To remove chloramines and reduce organic carbon. Catalytic carbon is needed for effective chloramine removal.
#
# 2.  **Primary Treatment (for TDS/Sulfate/Hardness):**
#     *   **Reverse Osmosis (RO):** This is the most practical technology for drastically reducing very high TDS, sulfate, hardness, and other dissolved ions. A system designed for brackish water or seawater treatment would be necessary given the 40,000 mg/L TDS.
#     *   **(Distillation):** Also highly effective at removing dissolved solids, but generally more energy-intensive than RO for significant volumes.
#
# 3.  **Post-treatment (Optional but Recommended after RO):**
#     *   **pH Adjustment:** RO water tends to be slightly acidic. Since the source water pH is high, the RO process might bring it closer to neutral, but post-treatment adjustment might still be needed (e.g., using a remineralization filter or calcite contactor if pH drops too low).
#     *   **Disinfection:** Although RO removes bacteria/viruses, a final disinfection step (like UV light) is often recommended for potable water systems as a safeguard.
#
# **Recommendation:**
#
# Given the extreme TDS level and multiple contaminants, this water source is likely unsuitable for direct use as drinking water without significant industrial-level treatment (desalination). Standard home filtration systems would be inadequate or quickly overwhelmed/damaged. Comprehensive testing, including for specific salts, heavy metals, and potential industrial pollutants, is strongly advised before considering any treatment strategy. This might be wastewater or highly impacted industrial process water rather than a typical source for drinking water.
