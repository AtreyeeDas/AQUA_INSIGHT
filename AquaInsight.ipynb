# %% [markdown]
# <a href="https://colab.research.google.com/github/AtreyeeDas/Water-Portability-Analysis/blob/main/AquaInsight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import warnings
import google.generativeai as genai
from google.generativeai import types

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

warnings.simplefilter("ignore")

import kagglehub

# %%
# Download dataset from Kaggle
path = kagglehub.dataset_download("uom190346a/water-quality-and-potability")
filepath = next(os.path.join(dirname, filenames[0]) for dirname, _, filenames in os.walk(path) if filenames)
df = pd.read_csv(filepath)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.11).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/uom190346a/water-quality-and-potability?dataset_version_number=2...
# 100%|██████████| 251k/251k [00:00<00:00, 60.0MB/s]
# Extracting files...

# %%
# Handle missing values
df.fillna(df.median(), inplace=True)

# Split features and target
X = df.drop("Potability", axis=1)
y = df.Potability

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=18, stratify=y)

# Balance data
smt = SMOTE()
X_train, y_train = smt.fit_resample(X_train, y_train)

# Normalize data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Train a RandomForest model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
def predict_potability(user_input):
    """Predicts water potability from user input."""
    input_data = np.array(user_input).reshape(1, -1)
    input_data = scaler.transform(input_data)
    prediction = model.predict(input_data)
    result = "\n💧 Water Quality Prediction 💧\n" + "="*30 + "\n"
    result += f"🔍 Analyzing water sample...\n"
    result += "✅ Safe to Drink! 😊" if prediction[0] == 1 else "⚠️ Not Safe for Drinking! ❌"
    return result

# %%
def analyze_with_gemini(user_input):
    """Analyzes water quality using Gemini API."""
    api_key = "AIzaSyB6TYePHsMOvGhgxXP-d-q5w4-KEuqRkQo"
    if not api_key:
        return "Gemini API key not found."

    genai.configure(api_key=api_key)
    model_name = "gemini-2.5-pro-exp-03-25"
    prompt = f"Given the water parameters {user_input} for  the format pH,Hardness (mg/L),Total Dissolved Solids (TDS) (mg/L),Chloramines (mg/L),Sulfate (mg/L),Conductivity (µS/cm), Organic Carbon (mg/L), Trihalomethanes (µg/L), Turbidity (NTU), is the water safe? If not, what are the contamination reasons and purification methods?"
    response = genai.GenerativeModel(model_name).generate_content(prompt)
    gemini_result = "\n🤖 AI Analysis from Gemini API 🤖\n" + "="*35 + "\n"
    gemini_result += response.text if response else "❌ No response from Gemini API."
    return gemini_result

# %%
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.073546
# 3273  9.419510  175.762646  33155.578218     7.350233  333.073546
# 3274  5.126763  230.603758  11983.869376     6.303357  333.073546
# 3275  7.874671  195.102299  17404.177061     7.509306  333.073546
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225        66.622485   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
# Collect user input
print("Enter water parameters in the following order:")
print(", ".join(X.columns))
user_input = []
for col in X.columns:
    value = float(input(f"Enter value for {col}: "))
    user_input.append(value)
# Out:
# Enter water parameters in the following order:
# ph, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic_carbon, Trihalomethanes, Turbidity
# Enter value for ph: 7.2
# Enter value for Hardness: 150
# Enter value for Solids: 900
# Enter value for Chloramines: 4.5
# Enter value for Sulfate: 250
# Enter value for Conductivity: 500
# Enter value for Organic_carbon: 10
# Enter value for Trihalomethanes: 70
# Enter value for Turbidity: 3

# %%
# Predict water quality and Get Gemini API Analysis
prediction = predict_potability(user_input)
gemini_analysis = analyze_with_gemini(user_input)

# %%
# Display details
print(prediction)
print(gemini_analysis)
# Out:
# 💧 Water Quality Prediction 💧
# ==============================
# 🔍 Analyzing water sample...
# ⚠️ Not Safe for Drinking! ❌
#
# 🤖 AI Analysis from Gemini API 🤖
# ===================================
# Okay, let's analyze these water parameters against standard drinking water guidelines (primarily EPA and WHO standards, which can sometimes differ slightly).
#
# **Water Parameters Provided:**
#
# 1.  **pH:** 7.2
# 2.  **Hardness:** 150.0 mg/L
# 3.  **Total Dissolved Solids (TDS):** 900.0 mg/L
# 4.  **Chloramines:** 4.5 mg/L
# 5.  **Sulfate:** 250.0 mg/L
# 6.  **Conductivity:** 500.0 µS/cm
# 7.  **Organic Carbon:** 10.0 mg/L
# 8.  **Trihalomethanes (THMs):** 70.0 µg/L
# 9.  **Turbidity:** 3.0 NTU
#
# **Analysis Against Standards:**
#
# 1.  **pH:** 7.2 - **Acceptable**. Standard range is typically 6.5 - 8.5.
# 2.  **Hardness:** 150.0 mg/L - **Acceptable (Aesthetic Issue)**. This level is considered "Hard". While generally safe to drink, it can cause scale buildup in pipes and appliances and affect soap lathering. No health-based limit, but classified as hard (typically >120 mg/L).
# 3.  **TDS:** 900.0 mg/L - **High / Potentially Unacceptable**.
#     *   EPA Secondary (aesthetic) Standard: ≤ 500 mg/L.
#     *   WHO: < 600 mg/L is considered good; 600-900 mg/L is fair; 900-1200 mg/L is poor.
#     *   This level exceeds the EPA aesthetic limit significantly and is at the threshold between "fair" and "poor" by WHO standards. It can affect taste (salty, bitter, or metallic).
# 4.  **Chloramines:** 4.5 mg/L - **Exceeds Limit / Unacceptable**.
#     *   EPA Maximum Residual Disinfectant Level (MRDL): 4.0 mg/L (as Cl2).
#     *   WHO guideline for monochloramine: 3 mg/L.
#     *   This level exceeds the maximum allowable disinfectant residual, potentially causing taste/odor issues and indicating improper disinfection control.
# 5.  **Sulfate:** 250.0 mg/L - **Acceptable (Borderline Aesthetic)**.
#     *   EPA Secondary (aesthetic) Standard: ≤ 250 mg/L.
#     *   WHO notes potential taste issues >250 mg/L and laxative effects >500 mg/L.
#     *   This level is right at the EPA aesthetic limit and may contribute to taste.
# 6.  **Conductivity:** 500.0 µS/cm - **Acceptable (Indicator)**. There's no direct standard, but it correlates with TDS. This value seems somewhat low relative to the high TDS reading (TDS often ≈ Conductivity * 0.55-0.7), but it doesn't independently indicate a safety issue beyond reflecting the dissolved solids present.
# 7.  **Organic Carbon:** 10.0 mg/L - **High / Concern**. There's no direct drinking water limit for TOC itself, but it's a precursor for disinfection byproducts (DBPs) like THMs. High TOC in treated water suggests potential issues with source water quality or treatment effectiveness, and increases the risk of DBP formation. This level is quite high for finished drinking water.
# 8.  **Trihalomethanes (THMs):** 70.0 µg/L - **Acceptable (Approaching Limit)**.
#     *   EPA Maximum Contaminant Level (MCL): 80 µg/L (for Total THMs).
#     *   While technically below the limit, it's close, especially concerning given the high Organic Carbon and high Chloramine levels which could lead to further formation.
# 9.  **Turbidity:** 3.0 NTU - **High / Unacceptable**.
#     *   WHO Guideline: < 5 NTU, ideally < 1 NTU for effective disinfection.
#     *   EPA Treatment Technique: Requires turbidity ≤ 1 NTU, often ≤ 0.3 NTU for effective filtration.
#     *   High turbidity interferes with disinfection by shielding microorganisms and indicates inadequate filtration. It's a significant health concern as it can correlate with the presence of pathogens.
#
# **Conclusion: Is the water safe?**
#
# **No, this water is not considered safe for drinking** based on standard guidelines.
#
# **Contamination Reasons:**
#
# 1.  **High Turbidity:** Suggests insufficient filtration, allowing suspended particles (silt, clay, organic matter, potentially microorganisms) to remain. This poses a risk because pathogens can be shielded from disinfectants.
# 2.  **High Chloramines:** Exceeds the maximum residual disinfectant level. This could be due to overdosing at the treatment plant or issues in the distribution system. While disinfectant is necessary, excessive levels are not permitted.
# 3.  **High Total Dissolved Solids (TDS):** Exceeds aesthetic limits and indicates a high concentration of dissolved substances (minerals, salts). While primarily an aesthetic issue impacting taste, very high levels can be problematic.
# 4.  **High Organic Carbon:** Indicates a significant amount of organic matter, which acts as a precursor for potentially harmful disinfection byproducts (like THMs) when reacting with disinfectants (like chloramines).
# 5.  **Borderline High THMs:** While currently under the limit, the level is close, and the conditions (high TOC, high chloramines) are conducive to their formation, raising concerns about potential chronic exposure risks.
#
# **Purification Methods:**
#
# To make this water potable, a multi-barrier approach targeting the specific contaminants is needed, typically at the point of use (e.g., under-sink system):
#
# 1.  **Sediment Pre-filtration:** To address **High Turbidity**. A filter (e.g., 1-5 micron rating) will remove suspended particles like silt, sand, and clay. This is crucial as a first step to protect subsequent filters.
# 2.  **Activated Carbon Filtration (Specifically Catalytic Carbon):** To address **High Chloramines**, **High Organic Carbon**, and **THMs**. Catalytic carbon is more effective than standard activated carbon at breaking down chloramines. It also adsorbs organic compounds (reducing TOC) and existing THMs.
# 3.  **Reverse Osmosis (RO):** To address **High TDS**. RO membranes are very effective at removing dissolved salts, minerals, and many other contaminants, significantly lowering TDS levels. RO also provides an additional barrier against bacteria, viruses, heavy metals, and reduces sulfates and THMs.
# 4.  **(Optional) Post-filter / Remineralization:** RO water can be slightly acidic and stripped of minerals. A carbon post-filter can polish the taste, and some systems add a remineralization stage to add back beneficial minerals (like calcium and magnesium) for improved taste and pH balance.
#
# **Recommended System:**
#
# A Point-of-Use (POU) multi-stage system incorporating:
# *   Stage 1: Sediment Filter (for Turbidity)
# *   Stage 2: Catalytic Carbon Block Filter (for Chloramines, TOC, THMs, Taste/Odor)
# *   Stage 3: Reverse Osmosis Membrane (for TDS, Sulfates, residual contaminants)
# *   Stage 4: Carbon Post-Filter (for final taste polishing)
#
# **Important Note:** This assessment is based on the single data point provided. Consistent monitoring and professional water testing are recommended for a complete understanding of water quality and appropriate treatment solutions.
